# %% [markdown]
# # 🎬 SECTION 1 : WELCOME & WHY CODEX
#
# **Goal of this section :**
# Hook the beginner in 90 seconds.
# Show what Codex can do that ChatGPT cannot.
# And set realistic expectations for this 3-hour course.
#
# **Lectures :**
# 1. Course Intro — What You Will Build
# 2. What Codex Is (and Isn't) for Beginners
# 3. Codex vs Cursor vs GitHub Copilot — The 1-Minute Comparison

# %% [markdown]
# # Lecture 1 : Course Intro — What You Will Build

# %%
'''

"Hi there, and welcome !

Before I tell you anything about this course…
Let me show you what YOU will build by the end of it.


-- [SHOW THE FINISHED MINI-PROJECT ON SCREEN — 30 seconds] --


👉 This is a Personal Coding Assistant.
👉 It runs inside your terminal.
👉 You type one sentence in plain English…
👉 And it READS your project files.
👉 It WRITES new code for you.
👉 It RUNS the code itself.
👉 It even FIXES the bugs on its own.


Watch this real quick —
    I am going to type :   'Add a login page to my app'
    Press Enter…
    And just look at what happens..

    Codex opens the project.
    Reads the files.
    Creates a new file — login.py
    Writes the full code.
    Runs the test.
    Tells me — done ✅

I did not write a single line of code.
I just spoke to it like a teammate.


And THIS is what you are going to build by the end of this course.


Now — the important part —

    I want to be very honest with you about what is in this course
    and what is NOT in this course.
    Bcz too many courses promise the moon and waste your time..


✅ WHAT IS IN THIS COURSE :

    👉 Codex CLI/IDE/Cloud setup from zero — even if you have NEVER used anyone one of them !
    👉 The mental model — how Codex actually 'thinks'
    👉 The K.I.M. Prompt Framework — my personal system to write prompts
       that work the FIRST time
    👉 AGENTS.md — the secret file that gives Codex memory of YOUR project
    👉 Real Codex CLI commands you will use every single day
    👉 ONE hands-on mini-project — your own Personal Coding Assistant
    👉 A career playbook at the end — where to go from here


❌ WHAT IS NOT IN THIS COURSE :

    👉 This is NOT a Python course
    👉 This is NOT a 'become a senior engineer in 3 hours' course
    👉 We are NOT covering 50 different AI tools
    👉 We are NOT touching the OpenAI API or paid model fine-tuning
    👉 We are NOT building 10 different projects — only ONE solid project
       that teaches every core concept


Why only ONE project ?

    Bcz I have taught thousands of students…
    And the truth is —
        Building 1 project DEEPLY teaches you 10x more
        than building 10 projects shallowly.

    You don't need more projects.
    You need ONE project where every concept clicks.


Realistic expectation —

    👉 By the end of 3 hours, you will be comfortable using Codex.
    👉 You will know how to talk to it.
    👉 You will know how to set up a project for it.
    👉 And you will have a working AI coding assistant on your machine.

    You will NOT be a Codex master in 3 hours.
    Mastery comes from using it on YOUR own real projects after this course.
    But you will have a complete, solid foundation.


One more thing —

    👉 No prior AI knowledge needed.
    👉 No prior coding background needed (basic file & folder comfort is enough).
    👉 You just need a laptop, internet, and 3 focused hours.


Sounds fair ?
Then let's jump in.

In the next lecture — we will answer the most important question of all :
    What exactly IS Codex ?
    And how is it different from ChatGPT that you already use ?

See you there !"

'''

# %% [markdown]
# # Lecture 2 : What Codex Is (and Isn't) for Beginners

# %%
'''

"Okay so — let's clear up the BIGGEST confusion first.

Most beginners think —
    'Codex is just ChatGPT for coding, right ?'

    No.
    Not at all.
    They are completely different..

Let me explain in plain English first !

In short , Codex =  GPT Models / ChatGPT + Tools 


========================================
PART 1 — What ChatGPT Does
========================================

When you use ChatGPT for coding, here is what happens :

    👉 You open CHATGPT
    👉 You COPY some code from your project.
    👉 You PASTE it into ChatGPT.
    👉 You ASK — 'Hey, fix this bug.'
    👉 ChatGPT gives you new code back.
    👉 You COPY that code.
    👉 You GO BACK to your IDE/editor.
    👉 You ran the new code 


So basically —
    👉 ChatGPT is a really smart friend on a phone call.
    👉 It can talk about your code.
    👉 But it cannot TOUCH your code.
    👉 YOU are the messenger between ChatGPT and your computer.

    It xant touch your Project Code bcz it does not have access to your System !
    But when u give access of system via Tools like : 
    Now using Tools , it can 

    ✅ Read files from your computer using File Reading Tool
    ✅ It can Write code for your Project using Code Writing Tool
    ✅ It can Run commands using Terminal / Bash Tool
    ✅ It can search the entire Internet using Web Search Tool

    


So if I simplify everything into one powerful line:

👉 Codex = Brain (LLM/ChatGPT) + Tools (Action Layer)



========================================
PART 2 — What Codex Does
========================================


In short , Codex is OpenAI's AI CODING AGENT.


        Like You say:
        “Find latest Python version and update my Project code as per latest version”
    
        Codex :
        👉 Searches web using Web search Tool
        👉 Opens python file on its own
        👉 Update the code
        👉 Runs the test to confirm the fix
        👉 Tells you — 'Done ✅'




You did NOTHING.
    No copy.
    No paste.
    No file switching.

That is the difference between a CHATBOT and an AGENT.

    👉 ChatGPT TALKS about code.
    👉 Codex DOES the work on your code.





========================================
FINAL TAKEAWAY
========================================

    👉 ChatGPT TALKS about code.
    👉 Codex DOES the work — reads, edits, and runs code on your machine.



And in the next lecture — we will quickly compare Codex with the other
three big names you have probably heard of — Claude , Cursor and GitHub Copilot.

Bcz I want you to know exactly WHY we are picking Codex for this course.

See you there !"

'''

# %% [markdown]
# # Lecture 3 : Codex vs Claude Code vs Cursor vs GitHub Copilot — Quick Comparison !

# %%
'''

"Okay so — by now you might be thinking…

    'Hey , I have already heard of Cursor.'
    'I have already heard of GitHub Copilot.'
    'How is Codex any different ?'
    'And which one should I actually use ?'


So Let me clear it up in simple words !


-- [SHOW THE COMPARISON SLIDE ON SCREEN] --



In short , All 3 are AI coding tools.
But each one is built for a totally different style of work.


------------------------------------------------------------
 TOOL              |  WHAT IT IS         |  HOW IT FEELS
------------------------------------------------------------
 GitHub Copilot    |  Smart autocomplete |  Tab-tab-tab
 Cursor            |  AI-first IDE       |  A whole editor
 Codex             |  Autonomous agent   |  A teammate
------------------------------------------------------------


Let's break each one down in simple terms : 


========================================
1️⃣  GITHUB COPILOT  =  AUTOCOMPLETE
========================================

Copilot is the OLDEST of the three.
It lives INSIDE your editor — like VS Code.
            [SHOW Copilot in VS CODE]

How it works :

    👉 You start typing code.
    👉 Copilot suggests the next line in grey text.

Think of Copilot like —
    👉 Predictive text on your phone keyboard.

👉 BEST FOR :  experienced devs who want faster typing




========================================
2️⃣  CURSOR  =  AI-FIRST IDE
========================================

Cursor is NOT just a plugin.
Cursor is a WHOLE editor — built from the ground up around AI.

Think of it as —
    👉 VS Code…
    👉 But with AI built into every corner.


Inside Cursor :

    👉 You can chat with your code in a side panel
    👉 You can highlight code and ask questions



Cursor is GREAT —
But it forces you to switch your editor.
    👉 You have to leave VS Code.
    👉 You have to learn a new app.


========================================
3️⃣  CODEX  =  AUTONOMOUS AGENT
========================================

Now — Codex.
Codex is built differently from BOTH of them.

Codex is an AGENT.
    👉 It does NOT live in autocomplete.
    👉 It does NOT force you to use a new editor.
    👉 It runs in your TERMINAL — wherever you already are.
        ( be in VSCode , Pycharm etc )
        [ show in teminal , VSCODE]



    👉 SO When You give Codex a TASK in plain English.
    👉 It plans the steps,  read your files  , edit those files & do end-2-end task !


👉 BEST FOR :  beginners + working devs who want to delegate full tasks



========================================
SO WHICH ONE SHOULD YOU PICK ?
========================================


Here is my honest recommendation —


    👉 If you just want faster typing in VS Code  →  GitHub Copilot
    👉 If you want a full AI-native editor        →  Cursor
    👉 If you want to DELEGATE real tasks         →  Codex ✅





Why ?
    👉 Bcz Codex is the closest to how AI coding will work in the future.
    👉 You give a goal. The agent does the work.
    👉 That is the entire direction the industry is moving in.

    Autocomplete is yesterday.
    Agents are today & tomorrow.




Alright — that's the end of Section 1.

    👉 You know what we are building.
    👉 You know what Codex is and isn't.
    👉 How Codex is different from CHATGPT !
    👉 You know how it compares to Cursor and Copilot.

Now in the next section — we get our hands dirty.
We will install Codex by following simple steps  —


See you in Section 2 !"

'''
