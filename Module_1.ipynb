# %% [markdown]
# # 1... Welcome to the Course !

# %%
'''
Hi its a quick course where we will perform Data analytics  , EDA & craete stunnign dashbaords from the CSV / excels or json
type of data u have !

SEe what used to hours of training , hours of Analysis,  Now 
it can done within using Claude & we will show u how to it professioanlly 


In this course , we will use Claude AI as a necessary tool 
CSV file dta whicu can follow for the course 
(again u can use any of the CSV file u have , & u can do indepth data analysis )


we will use Python packages like ( pandas , plotly , streamlit for doing data analysis )




I will guide u step by step :
U do not need to be expert in data analytics 
U do not need to be a programmer 
No need to know have any prior knowledge  , we will show u things from scratch !


Lets understand  , why is this USEful ?
See in this world of Data , if u are able to turn informations or Data into such quick dashboards is a huge advantage !

& thats where Claude comes into picture !

so yeah ,  just ready with me & u will be doing AI-powered Data analytics within minsutes using Claude 
that u have never imagined !






'''

# %% [markdown]
# # 2.. Why Claude AI is Perfect for Data Analytics !

# %%
'''



Hi, let’s understand why Claude AI is becoming so powerful for Data Analytics!
But before that, let’s first understand what Data Analytics actually means.

If we split the term itself:

Data → Raw information
Analytics → Finding patterns, insights from data 

So basically:
    When we apply analysis techniques on data, we get meaningful insights that help 
    businesses , organisations & companies make better decisions.



These insights help companies improve:

    Revenue 📈
    User engagement 👥
    Customer experience ⭐
    Business growth 🚀



Lets connect it with the real world Scenario :

Imagine u are Data Analyst at Youtube & You receive huge amounts of data in Excel or CSV files like:
(USer_name , Watch_Time , Video_Category , Device_Type , Country)

Now your job is to analyze this data and discover useful business insights.


Example Insights
    Users spend more time watching Shorts at night 🌙
    Gaming videos get higher engagement among teenagers 🎮
    Videos under 8 minutes get higher completion rates ⏱️
    Educational channels have better subscriber retention 📚

        
        
        So to come up with such insights,  first data Analyst :
        Collect data ( databases, APIs, Excel files )
        Clean Data 
        Exploratory Data Analysis (Find trends , patterns)
        Data Viz (Create charts and graphs)
        Dashboards ( Present insights to stakeholders )
        
        
        & this 5 step process in time-consuming , manual & repeatitive as well 
        & Thats where Claude Comes into picture !
        Now claude is able to Automate almost 90% of the Entire Workflow !
        
        Like u say to Claude, Hey this is data we have , can u clean it !
        Claude will find fixes , it will clean it & have to just review the work !

        Instead of doing everything manually, the analyst now mainly:

        Reviews results
        Verifies insights
        Makes business decisions



'''

# %% [markdown]
# # 3.. Meet the Stock Market Dataset (what each column means) !

# %%
'''

Hi before start understanding our data , doing analysis & creating dashbaords 
Lets first have a look on the data we have !

Bcz better the understand data , better Insights u can make from this data !



Column Name	Meaning


Date	The trading date of the stock
Open	Stock price when the market opened
High	Highest stock price during the day
Low	Lowest stock price during the day
Close	Final stock price when the market closed
Adj Close	Adjusted closing price after stock splits/dividends
Volume	Total number of shares traded that day



'''
