# %% [markdown]
# # 1.. Plan Your Stock Dashboard with Claude AI

# %%
'''

Hi , So far, we have learned how to perform EDA (Exploratory Data Analysis) and generate meaningful insights from data.

Now it’s time to take the next step —
converting those insights into interactive dashboards.

Because in a real company environment,
your analysis becomes truly valuable only when it can be clearly presented to:

• Managers  
• Business Teams  
• Stakeholders  
• Decision Makers  


'''

# %%
'''

Prompt 5: Tell Claude What Dashboard You Want


I want to build a professional Stock Market Dashboard using this dataset.

Dashboard should include:
- KPI cards
- Stock price trend chart
- Candlestick chart
- Trading volume chart
- Moving average charts
- Daily return analysis
- Date filters
- Interactive charts
- Modern clean layout

Keep the dashboard beginner-friendly and visually attractive..


[takes arond 60% of Claude usage]
'''

# %%
'''
It has actually used HTML along with CSS to gneerate this dashbaord !

So Claude have actually saved 90% of your work !
Now your new role is to review , refine & turn this Dashboard into Professional one !



'''

# %% [markdown]
# # 2.. Build an Interactive Stock Market Dashboard with Claude AI !

# %%
'''

Prompt 6: Generate the Interactive Dashboard

Create a complete interactive Streamlit dashboard for this stock market dataset..

Requirements:
- Use Plotly charts
- Add sidebar filters
- Add KPI metrics
- Create interactive charts
- Keep code simple and beginner-friendly
- Add comments in code
- Generate index.html file


Make the dashboard look modern and professional.






'''

# %% [markdown]
# # 3.. Publish It Online with One Click

# %%
'''


Hellow & welcome to this lesson of "Publishing & Sharing the Dashbaord" so that anyone can see your work !
& yes Claude gives us that Feature !

That means:

• No need to set up a separate server  
• No need to purchase a domain  
• No complex deployment process 




'''
