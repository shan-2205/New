# %% [markdown]
# # 1.. Why Skills are Important ?

# %%
'''

Hi there 👋 , Welcome to one of the MOST powerful sections of this entire Claude Code course !

In this section , we are going to deep dive into something called : Skills 🚀
And trust me , this is one of the HOTTEST topics right now in the entire Claude ecosystem !

        
    So whether u are using Claude as a chatbot , or as a coding agent , or for Cowork ,
    Skills will give u SUPER POWERS !


So Before understanding what Skills are , first lets understand WHY Skills are important ?
    

So lets break this down with simple examples :

👉 See , LLMs like Gemini , ChatGPT , Claude — 
    They are GENERAL PURPOSE Language Models !
    
    What does General Purpose mean ?
        👉 It means they have the capability of writing , coding , reasoning , 
           translating , summarizing — across various domains !
        👉 They are like a Jack of all Trades !



But here's the PROBLEM 🚨 :

    👉 These LLMs are GOOD at general capabilities ..
    👉 But NOT for specific-task types !

    These models LACK , when u ask them to execute SPECIAL tasks !


Lets understand it using a real-world example 🎯 :

    Example 1 : Imagine you work in a company …
                & your job is to create PPTs & present it to higher management !

                So , what can u do ?
                👉 You can use Claude to generate PPTs ...

                Now , Claude is ABLE to create PPTs very well .. ✅
                But Claude doesn't create VERY GOOD PPTs as YOU want it !
                
                Why ?
                    👉 Bcz Claude does not know how to handle layout ..
                    👉 Claude doesn't know what type of fonts to use for YOUR Company PPT
                    👉 Claude does not know WHERE to put charts & tables ..
                    👉 Claude doesn't know YOUR company's design guidelines !
                    
                Bcz Claude only has GENERAL Capability !



    Example 2 : Similarly , if you are doing DATA ANALYSIS 📊

                In such a case , LLMs can do general data analysis ..
                But to do SPECIFIC data analysis as per YOUR task , Claude may not do that !



    Example 3 : Similarly , if you are a CONTENT CREATOR / BLOG WRITER ✍️

                Then Claude will NOT know :
                    👉 How you write your documents 
                    👉 How you write your scripts
                    👉 What is YOUR personal writing style ?



    Example 4 : Similarly , if you are a SENIOR MANAGER / DEVELOPER 👨‍💻

                Then Claude will NOT know how to review the code AS PER YOUR company standards !


& that's where the IDEA of SKILLS comes ✨ ...
        Bcz LLMs are good at general tasks , but they don't do well on SPECIALISED tasks !



Q. Now you may say : if I have to do some specialized task , I can create a DETAILED prompt
   in that prompt , I will add ALL the instructions to do that task !

Ans : Yes , thats a valid thought , BUT it creates MORE problems , for example :

    👉 Problem 1 : (Imagine if u have to create PPT again & again , for that u have to put prompt again & again..)
                   
                   So You will say : I will save it as a SYSTEM PROMPT !
                   
                   But imagine system prompt CONSUMES 120K tokens , then Context window gets filled !
                  & LLM will miss some imp info !



    👉 Problem 2 : You can't add resources in prompt , (like refer such charts , such fonts) ,
                   but how to attach it in Prompts ? — 
                   
                   this is one MORE problem !



    👉 Problem 3 : You can't share & improve this prompt with your team !



So whenever you want to do some task AGAIN & AGAIN with :
            👉 Reliably 
            👉 + Repeatedly 
            👉 + with Specialised prompts

That's where the IDEA of SKILLS comes ✨ ..
( bcz even using specialized prompts , this task is impossible to do it ! )


And in the next session …
We'll understand WHAT exactly are Skills & how they SOLVE all these problems 🚀

'''

# %% [markdown]
# # 2.. What are Skills ?

# %%
'''

Hi there 👋 , In the last session …
We understood WHY Skills are important !

Now lets understand : 👉 WHAT exactly are Skills ?


🎯 Definition :

    Skills are a FOLDER inside a Project where we keep DIFFERENT files & 
    with the help of these files , Agents/LLMs are able to understand HOW to carry a SPECIALISED task !
    
    
    In simple words :
        👉 Claude will load Skills ONLY in context , WHEN IT IS NEEDED !


Example : 
    When you say to Claude — "Hey Claude , generate a PPT for me"
    Then only , Claude will go to the Skill folder ,
    load necessary files , follow instructions of that file & THEN create PPT for you 🚀




Now lets understand the STRUCTURE of Skills 📂 :


    👉 Skills is nothing but a FOLDER inside a project !


    Here is the basic hierarchy :

    📁 Project folder
        └── 📁 .claude folder
              └── 📁 skills folder
                    └── 📁 skill folder
                          └── 📄 SKILL.md   ← (Very important file !)



👉 Inside the skill folder , we have a file called SKILL.md
    
    🚨 If this file is missing , then Skill will NOT work !

👉 Inside SKILL.md file , ALL the detailed instructions have been written 
   to perform some specific task !

    eg : if I have to create a PPT , then :
        👉 What will be PPT style ?
        👉 What will be Typography ?
        👉 When to use graphs & charts ?
        
    All these instructions live inside SKILL.md !



👉 Apart from this , if YOUR Skill needs RESOURCES to perform that task ,
   then you can actually create SUB-FOLDERS & put resources inside that !


    📁 skill folder
        ├── 📄 SKILL.md
        ├── 📁 scripts/        ← sub-folder
        ├── 📁 templates/      ← sub-folder
        └── 📁 resources/      ← sub-folder



Lets understand these sub-folders with examples :

    👉 Like in scripts/ folder :
            Imagine u are doing data analysis ..
            Then u may need some Python code to perform data analysis ,
            Then u can actually put all the code inside scripts/ folder ! 🐍



    👉 In templates/ folder :
            Like u are creating PPTs & for that u may need :
                👉 Company design guidelines 🎨
            You can put these company guidelines into templates/ folder ! ✨



    👉 In resources/ folder :
            Any extra reference material , images , data files , etc.
            can go inside resources/ folder !



🎯 Proper Hierarchy of a Project with Multiple Skills :

    📁 Project folder
        └── 📁 .claude folder
              └── 📁 skills folder
                    ├── 📁 skill folder 1
                    │     ├── 📄 SKILL.md
                    │     └── 📁 optional resources
                    ├── 📁 skill folder 2
                    │     └── 📄 SKILL.md           ← (this is another Skill !)
                    └── 📁 skill folder 3
                          └── 📄 SKILL.md           ← (this is another Skill !)




And in the next session …
We'll go EVEN DEEPER and understand the internal structure of SKILL.md file 
( YAML Front-matter + Markdown Body ) — this is where the REAL magic happens 🔥


'''

# %% [markdown]
# # 3.. Skills Deep-dive : YAML Front-matter + Markdown body

# %%
'''

Hi there 👋 , In the last session …
We understood WHAT Skills are & the FOLDER structure of Skills !


So now , lets deep dive into how to create Skills !

Imagine u want to Generate the daily tax report from amazon_sales_data.csv !
[VS CODE] :


So u have to give this prompt : 

" Generate a daily tax & Revenue report from amazon_sales_data.csv "
Then Claude may generate some code & return us "TAX REPORT"


->> But Amazon may have their own guidelines regarding Taxes which Claude will not aware about that !
->> Similarly Claude will not aware about the GST rate, YOUR invoice template that Managers want !
    So this is a specialised + REliable + Repeated task & thats where the idea of SKILLS comes into picture !
    



So before creating Skills , first lets understand components of Skill & then in the next session , 
I will show u practical Part !




Lets understand : 👉 What does the Skill file which is SKILL.md ACTUALLY contains ?


     👉 SKILL.md actually has 2 IMPORTANT things :

        1) YAML Front-matter
        2) Markdown Body


Lets understand each of these one by one 👇




═══════════════════════════════════════════════
1) 📝 YAML Front-matter
═══════════════════════════════════════════════

YAML Front-matter is the TOP section of the SKILL.md file !
It has 2 things :

    👉 a) Skill name
    👉 b) Description




👉 a) Skill name :
            Using skill-name , Claude can IDENTIFY the skill !


👉 b) Description :
            Description is VERY IMPORTANT bcz ..
            After reading the description , Claude knows WHEN to use or load this Skill !




    
    Example :- You are creating a Skill for calculate daily revenue, GST 📊 ,
                  Then in description you have to CLEARLY mention :
                  
                  " Use this Skill whenever the user wantsto calculate daily revenue, GST, or 
                    net profit from a sales CSV "  



    🔥 So , description is like a TRIGGER for Claude ,
       like — "Hey Claude , WHEN to use or load this Skill !"




═══════════════════════════════════════════════
2) 📄 Markdown Body
═══════════════════════════════════════════════

    Here we WRITE DOWN EVERYTHING :-
    
    👉 All the instructions
    👉 + Code (if needed)
    👉 + Coding patterns
    👉 + Validation patterns


    + All files/references , like if u need Python script for Tax calculation  ,
       so here you can LINK that !



🎯 Lets visualize how a SKILL.md file looks :


```md
┌──────────────────────────────────────────────────────────────┐
│  ---                                                        │
│  name: revenue-tax-splitter                                 │
│  description: Use this Skill whenever the user wants        │
│               to calculate daily revenue, GST, or           │
│               net profit from a sales CSV                   │
│  ---                                                        │
│                                                             │
│  # 🏢 Our Company Tax Rules                                 │
│                                                             │
│  | Product Category                          | GST Rate |   │
│  |-------------------------------------------|----------|   │
│  | Laptop, Smartphone, Tablet, Monitor       | 18%      |   │
│  | Headphones, Power Bank                    | 18%      |   │
│  | Keyboard, Mouse, USB Cable, Charger       | 12%      |   │
│                                                             │
│  Profit Margin: 20% on Net Revenue (after GST)             │
│                                                             │
│  ## Instructions                                            │
│                                                             │
│  - Calculate Gross Revenue = Quantity × Price               │
│  - Separate GST according to product category               │
│  - Compute Net Revenue after GST deduction                  │
│  - Generate daily sales summary                             │
│  - Create accountant-ready Markdown report                  │
│                                                             │
│  ## 📚 Files Used                                           │
│                                                             │
│  - scripts/tax_split.py                                     │
│      → Tax calculation logic                                │
│                                                             │
│  - templates/tax_report_template.md                         │
│      → Standard finance report format                       │
│                                                             │
└──────────────────────────────────────────────────────────────┘
```


🟢 Quick Summary :

    👉 YAML Front-matter  =  Identity card (name + description)
    👉 Markdown Body      =  The detailed instruction manual

    👉 Name        →  Tells Claude — "Who am I ?"
    👉 Description →  Tells Claude — "WHEN to use me ?"
    👉 Body        →  Tells Claude — "HOW to do the task ?"



& in the next session …
We will understand HOW Claude actually LOADS these Skills internally —
This is where you'll learn about a beautiful concept called : "Progressive Disclosure" 🚀


'''

# %% [markdown]
# # 4.. [ Live DEMO ]

# %%
'''

Why specialized? 

Claude doesn't know YOUR GST rate, YOUR invoice template, or YOUR HSN codes by default. 
& believe me , Every businesses needs such Automation !




'''

# %%
'''

Generate Skill 


'''

# %%
'''

Ask Claude : 


Generate a daily tax & Revenue report from data/amazon_sales_data.csv

How much GST do we owe today?

Daily tax report please




#     Claude will :
#         1. Scan all Skills available ( YAML descriptions )
#         2. Match your revenue-tax-splitter Skill
#         3. Load SKILL.md body into context
#         4. It will load Code for code patterns
#         5. Use templates/report_template.md as output format
#         6. Generate Final Report 📊
#



'''

# %%
'''

For your tax task, a slash command would look like this:
You create a file at:

.claude/commands/tax-report.md


Inside tax-report.md


---------------------------------------------------------

Generate a daily tax report from data/amazon_sales_data.csv.

Apply these GST rates:
- Laptop, Smartphone, Tablet, Monitor, Headphones, Power Bank → 18%
- Keyboard, Mouse, USB Cable, Charger → 12%

Profit Margin: 20% on Net Revenue.

Show Gross Revenue, GST, Net Revenue, Net Profit.
Save report to reports/tax_report.md

---------------------------------------------------------






Then in Claude Code, you call it by typing : /tax-report




# ⚖️ But Here's the Real Difference

This is the **most important teaching point** for students 👇

| Feature                      | Slash Command `/tax-report`     | Skill `revenue-tax-splitter`                                  |
| ---------------------------- | ------------------------------- | ------------------------------------------------------------- |
| **How it runs**              | You manually type `/tax-report` | Claude detects it automatically  
|
| **Who decides execution**    | YOU must remember the command   | Claude intelligently triggers the workflow                    |            |
| **Supporting files**         | ❌ Only one `.md` file            | ✅ Full skill folder with `SKILL.md`, `scripts/`, `templates/` |
| **Reusable Python logic**    | ❌ Cannot reference `tax_split.py`| ✅ Loads and runs tax_split.py                        |                     |
| **Report consistency**       | ❌ Output format varies each run  | ✅ Always uses tax_report_template.md                     |
                   |
                   |

---









Use a Slash Command when:

✅ Task is short — fits in one prompt
✅ You'll always remember to call it
✅ No supporting scripts or templates needed
✅ Output format doesn't need to be consistent

Use a Skill when:

✅ Task is complex — needs scripts + templates
✅ You want Claude to trigger it automatically
✅ Output must be identical every time
✅ Task needs YOUR company's business logic baked in




💡 The One-Liner for Your Lecture
    "A Slash Command is something YOU trigger. A Skill is something that triggers ITSELF."





'''

# %% [markdown]
# # 5.. How Does Claude load Skills ?

# %%
'''

Hi there 👋 , In the last session …
We understood the internal structure of SKILL.md ( YAML + Body ) & we have hands-on as well !

Now , lets understand : 👉 HOW does Claude actually LOAD Skills ?
This is one of the MOST elegant concepts in the entire Claude ecosystem 🚀


🎯 The Big Idea : Progressive Disclosure


👉 Claude follows the idea of : PROGRESSIVE DISCLOSURE

    What does this fancy word mean ?
    
        👉 i.e Don't present info until it is needed !
                            OR
        👉 i.e Don't load that info in context window until it is needed !



🤔 Why does Claude do this ?

    See , Context Window is LIMITED !
    That's why , we don't load Skill in memory until it is loaded ..
    ( Bcz if we dump everything at once , context window will FILL UP very fast 🚨 )


    Think of it like this 💡 :
        Imagine u walk into a library 📚 ..
        You don't pick up EVERY book at once , right ?
        You go to the section you need , take the relevant book , and start reading !
        
        That's EXACTLY how Claude loads Skills !




🎯 Progressive Disclosure works at 3 LEVELS :


═══════════════════════════════════════════════
Level 1 :  The Description
═══════════════════════════════════════════════

    👉 The Skill's YAML front-matter ALWAYS gets loaded ,
       as it is very VERY small !

    👉 So if you have 10 Skills , then all the 10 Skill names & descriptions 
       actually got loaded in context !


    Why ?
        👉 Bcz Claude needs to KNOW : "What Skills are available to me ?"
        👉 It's like reading the menu 📜 before ordering food !




═══════════════════════════════════════════════
Level 2 :  SKILL.md ( loaded on-demand )
═══════════════════════════════════════════════

    So , when user asks to generate PPT ,
    Then Claude will SEARCH whether Skill is present or not ..
    
    👉 If Skill is available , then Claude will load body of that Skill & follow instructions !


    🎯 This is the BEAUTY of Progressive Disclosure :
        ( Translation : The moment it is actually needed , then only we will load/show it ! )

    Else our Context window will be FILLED very soon 🚨




═══════════════════════════════════════════════
Level 3 :  Supporting files / Resources
═══════════════════════════════════════════════

    👉 Even WITHIN SKILL.md , Claude is smart !
    👉 If SKILL.md references other files ( like scripts/ , templates/ ) ,
       Claude will load THOSE files ONLY when actually needed !


    So the loading happens like this 🎯 :

        Step 1 :  YAML loads instantly ( tiny )
        Step 2 :  When user asks for that task → SKILL.md body loads
        Step 3 :  If body references a file → that file loads
        





🟢 Lets visualize this :


    User : "Hey Claude , Generate a daily tax & Revenue report from amazon_sales_data.csv."
          ↓
    [ Claude scans all loaded YAML descriptions ]
          ↓
    [ Finds : Revenue-Tax-Splitter Skill matches ! ]
          ↓
    [ Loads SKILL.md body into context ]
          ↓
    [ SKILL.md says : "Use template.md for fonts & template" ]
          ↓
    [ Loads template.md into context ]
          ↓
    [ Generates Tax & Revenue Report 🎉 ]



🟢 Summary :

    👉 Level 1 : YAML descriptions  →  Always loaded ( small , cheap )
    👉 Level 2 : SKILL.md body      →  Loaded when needed
    👉 Level 3 : Supporting files   →  Loaded when referenced

And in the next session …
We'll explore the SKILLS MARKETPLACE — 
where you can DOWNLOAD ready-made Skills from the community or create your own !


'''

# %% [markdown]
# # 6.. Skills Marketplace..

# %%
'''

Hi there 👋 , In the last session …
We understood HOW Claude loads Skills using Progressive Disclosure !

Now , the question is : 👉 WHERE do we GET Skills from ?
& 👉 What are the DIFFERENT TYPES of Skills ?

Lets dive in 🚀




═══════════════════════════════════════════════
🎯 Types of Skills
═══════════════════════════════════════════════

There are basically 2 types of Skills :


👉 1) Personal Skills

        We save these Skills into HOME DIRECTORY :
        
            📁 ~/.claude/skills/
        

        These Skills are AVAILABLE ACROSS all your projects !
        ( Like your personal coding style , your design preferences )
        ( which we want for ALL the projects )
        



👉 2) Project-based Skills

        Which you can create for your CURRENT project ,
        & you can share it with your team !

        Will be stored in project directory as :

            📁 ./.claude/skills/


    🎯 Difference :
        👉 Personal Skill   →  Only YOU use it , across all your projects
        👉 Project Skill    →  Whole TEAM uses it , only for that project




═══════════════════════════════════════════════
🎯 Ways to Create Skills
═══════════════════════════════════════════════

There are 3 ways to CREATE/GET Skills :


👉 1) Create MANUALLY

        You can manually write the SKILL.md file ..
        
        🚨 But it is NOT GOOD for beginners ,
           bcz they don't have enough knowledge at Day 1 !
        
        ( This needs experience — once you build a few Skills , 
          you can write them by hand ! )




👉 2) Use Claude itself ✨

        You can use Claude AI / Chat to CREATE a Skill !

            Claude Chat
                ↓
            Skill 
                ↓
            Using this , you can create a Skill !
        
        🔥 This is the EASIEST & FASTEST way !
        Just describe what u want , Claude will generate the Skill for u !




👉 3) Install Skills from COMMUNITY Sources 🌍


        👉 Claude Skill Marketplace : skills.mp ( website )
        👉 You can Google as : "Claude Skill marketplace"
        
        
        Go to skills.mp website 🌐
            You can SEE various Skills from :
                👉 Marketing
                👉 Data Analysis 📊
                👉 Coding 💻
                👉 Content Writing ✍️
                👉 ... many more !



        🚨 IMPORTANT SECURITY NOTE :
        
            👉 Always READ Skills very carefully BEFORE using ,
               bcz they may have SECURITY FLAWS !
            
            👉 You can check Anthropic's PUBLIC repo of Skills on GitHub ,
               bcz it will NOT have security flaws ! ✅
            
            
            ( Think of it like installing Apps on your phone — 
              always use trusted sources ! )




═══════════════════════════════════════════════
🎯 Steps to Create a Skill ( the proper way ! )
═══════════════════════════════════════════════


👉 1) Identify Need 🔍

        Create Skill ONLY for those tasks which are :
            👉 Specialized 
            👉 + Repeatable
        
        🚨 Don't create a Skill for one-time tasks — that's overkill !



👉 2) Create directory of Skill & create SKILL.md file 📁
        
            📁 my-skill/
              └── 📄 SKILL.md



👉 3) Add DETAILED instructions inside SKILL.md file 📝

        👉 YAML front-matter ( name + description )
        👉 + Markdown body ( instructions + references )



👉 4) TEST the Skill 🧪

        Try it out !
        Ask Claude to do the task & see if the Skill triggers correctly ..
        Refine if needed 🔁



🟢 Summary :

    👉 Types of Skills      :  Personal  +  Project-based
    👉 Ways to Create       :  Manual  +  Use Claude  +  Marketplace
    👉 Trusted Source       :  Anthropic public GitHub repo ✅
    👉 4-Step Process       :  Identify  →  Create dir  →  Add instructions  →  Test



And in the next session …
We'll get our HANDS DIRTY 🔥 with a FULL DEMO :
👉 Sales Data Analysis Project using Claude Skills !


'''

# %% [markdown]
# # 7.. [ Hands -on ] : Installing Skills from Marketplace

# %%
'''

[VSCODE] -> Terminal -> /skills -> u can see available skills in this Project




/plugin ->> 



'''

# %%
'''

Hi there 👋 , Welcome to the most EXCITING part of this section !

In the last 5 sessions , we built up our theory 📚 ..
Now its time to get our HANDS DIRTY 🔥 with a REAL-WORLD demo !


🎯 The Demo : Sales Data Analysis Project 📊

    Imagine you work in a company , and every Monday morning ,
    your manager asks u to analyze last week's sales data ..
    
    👉 Same task , every week — REPEATABLE ✅
    👉 Specific output format — SPECIALIZED ✅
    
    This is the PERFECT use case for a Skill !



🎯 What we'll build :

    A Skill called : sales-analyzer
    
    It will :
        👉 Read a sales CSV file 📁
        👉 Clean the data 🧹
        👉 Generate insights 💡
        👉 Create charts 📈
        👉 Output a clean summary report 📄



🎯 Folder Structure we'll create :

    📁 sales-project/
      └── 📁 .claude/
            └── 📁 skills/
                  └── 📁 sales-analyzer/
                        ├── 📄 SKILL.md
                        ├── 📁 scripts/
                        │     └── 📄 analyze.py
                        └── 📁 templates/
                              └── 📄 report_template.md


Lets BUILD it step-by-step 🚀

'''

# %% [markdown]
# ## Step 1 : Create the Project & Skill folder structure

# %%
# Lets first set up our project folder structure
# Open your terminal & run these commands :

# Create main project folder
# mkdir sales-project
# cd sales-project

# Create the Skills directory structure
# mkdir -p .claude/skills/sales-analyzer/scripts
# mkdir -p .claude/skills/sales-analyzer/templates

# Final structure :
#
# sales-project/
#   └── .claude/
#         └── skills/
#               └── sales-analyzer/
#                     ├── SKILL.md           <-- we'll create this next
#                     ├── scripts/
#                     └── templates/

# %% [markdown]
# ## Step 2 : Create the SKILL.md file ( YAML + Markdown Body )

# %%
# Inside .claude/skills/sales-analyzer/SKILL.md
# Paste the following content :

skill_md_content = """---
name: sales-analyzer
description: Use this Skill whenever the user wants to analyze sales data, generate weekly sales reports, calculate revenue trends, identify top-selling products, or create sales summary insights from CSV files. Trigger this Skill on phrases like "analyze sales", "weekly sales report", "sales summary", or when a sales CSV file is shared.
---

# Sales Analyzer Skill

## Purpose
This Skill helps Claude analyze sales data from CSV files and produce a clean, executive-ready summary report.

## Instructions

When the user requests a sales analysis, follow these steps:

1. **Read the data**
   - Load the CSV file using pandas.
   - Check for missing values, duplicates, and incorrect data types.

2. **Clean the data**
   - Drop duplicates.
   - Fill missing numeric values with 0.
   - Convert date columns to datetime.

3. **Compute key metrics**
   - Total Revenue
   - Total Units Sold
   - Top 5 best-selling products
   - Revenue trend (week-over-week)
   - Region-wise performance

4. **Generate visualizations**
   - Bar chart: Revenue by Product
   - Line chart: Revenue over Time
   - Pie chart: Region-wise share

5. **Output**
   - Use the report template in ./templates/report_template.md
   - Reference helper code in ./scripts/analyze.py

## Style Guidelines
- Use INR currency format (Rs. XX,XXX)
- Round all numbers to 2 decimal places
- Use a clean, executive tone
- Always include 3 actionable insights at the end

## References
- ./scripts/analyze.py  — reusable Python analysis functions
- ./templates/report_template.md  — output report structure
"""

print(skill_md_content)

# %% [markdown]
# ## Step 3 : Create the helper Python script ( scripts/analyze.py )

# %%
# Inside .claude/skills/sales-analyzer/scripts/analyze.py
# This script provides REUSABLE functions that Claude can refer to

analyze_py_content = """
import pandas as pd
import matplotlib.pyplot as plt


def load_and_clean(csv_path):
    """Load CSV and perform basic cleaning."""
    df = pd.read_csv(csv_path)
    df = df.drop_duplicates()
    df = df.fillna(0)
    if 'date' in df.columns:
        df['date'] = pd.to_datetime(df['date'], errors='coerce')
    return df


def compute_metrics(df):
    """Compute key sales metrics."""
    metrics = {}
    metrics['total_revenue'] = round(df['revenue'].sum(), 2)
    metrics['total_units']   = int(df['units_sold'].sum())
    metrics['top_products']  = (
        df.groupby('product')['revenue']
          .sum()
          .sort_values(ascending=False)
          .head(5)
          .to_dict()
    )
    if 'region' in df.columns:
        metrics['region_share'] = (
            df.groupby('region')['revenue'].sum().to_dict()
        )
    return metrics


def plot_revenue_by_product(df, save_path='revenue_by_product.png'):
    """Bar chart of revenue by product."""
    grouped = df.groupby('product')['revenue'].sum().sort_values(ascending=False)
    grouped.plot(kind='bar', figsize=(10, 5), color='#4C72B0')
    plt.title('Revenue by Product')
    plt.ylabel('Revenue (Rs.)')
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()


def plot_revenue_trend(df, save_path='revenue_trend.png'):
    """Line chart of revenue over time."""
    trend = df.groupby('date')['revenue'].sum()
    trend.plot(kind='line', figsize=(10, 5), marker='o', color='#55A868')
    plt.title('Revenue Trend')
    plt.ylabel('Revenue (Rs.)')
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()
"""

print(analyze_py_content)

# %% [markdown]
# ## Step 4 : Create the report template ( templates/report_template.md )

# %%
# Inside .claude/skills/sales-analyzer/templates/report_template.md

report_template_content = """
# 📊 Weekly Sales Report

**Period :**  {start_date} to {end_date}

---

## 1. Headline Numbers

- **Total Revenue :**  Rs. {total_revenue}
- **Total Units Sold :**  {total_units}
- **Week-over-Week Growth :**  {wow_growth}%

---

## 2. Top 5 Products

| Rank | Product | Revenue |
|------|---------|---------|
| 1    | {p1}    | Rs. {r1} |
| 2    | {p2}    | Rs. {r2} |
| 3    | {p3}    | Rs. {r3} |
| 4    | {p4}    | Rs. {r4} |
| 5    | {p5}    | Rs. {r5} |

---

## 3. Region-wise Performance

{region_breakdown}

---

## 4. Visualizations

![Revenue by Product](revenue_by_product.png)

![Revenue Trend](revenue_trend.png)

---

## 5. 🔥 Key Insights

1. {insight_1}
2. {insight_2}
3. {insight_3}

---
*Generated by sales-analyzer Skill*
"""

print(report_template_content)

# %% [markdown]
# ## Step 5 : Test the Skill in Claude Code 🧪

# %%
# Now lets TEST our Skill ! 🎉

# Step 1 : Open terminal inside sales-project folder
# Step 2 : Launch Claude Code by typing :
#
#     claude
#
# Step 3 : Now , just ask Claude in plain English :
#
#     "Hey Claude , I have a sales CSV file called sales_data.csv ,
#      please analyze it and generate a weekly sales report for me"
#
# Step 4 : Watch the magic ✨
#
#     Claude will :
#         1. Scan all Skills available ( YAML descriptions )
#         2. Match your request with the sales-analyzer Skill
#         3. Load SKILL.md body into context
#         4. Reference scripts/analyze.py for code patterns
#         5. Use templates/report_template.md as output format
#         6. Generate charts + Final Report 📊
#
# Step 5 : You get a PROFESSIONAL sales report —
#          without typing a HUGE prompt every week ! 🚀
#
#
# 🎯 This is the POWER of Skills :
#         👉 Write once
#         👉 Reuse forever
#         👉 Reliable + Repeatable + Specialized

# %%
'''

🎉 CONGRATULATIONS ! 🎉

You just built your FIRST Claude Skill ! 🚀


Lets quickly RECAP what we did in this demo :

    ✅ Step 1 : Created the project folder structure ( .claude/skills/sales-analyzer/ )
    ✅ Step 2 : Wrote SKILL.md with YAML front-matter + Markdown body
    ✅ Step 3 : Added a Python helper script ( scripts/analyze.py )
    ✅ Step 4 : Added a report template ( templates/report_template.md )
    ✅ Step 5 : Tested the Skill in Claude Code !



🎯 What you should TAKE AWAY from this entire section :

    👉 Skills give Claude SPECIALIZED superpowers 💪
    👉 They are just FOLDERS with SKILL.md + optional resources
    👉 YAML tells Claude WHEN to use the Skill
    👉 Markdown body tells Claude HOW to do the task
    👉 Progressive Disclosure keeps context window CLEAN ✨
    👉 You can create , share & install Skills from the community 🌍



🔥 PRO TIP :

    Once you start building Skills for your daily tasks ,
    you'll realize — you'll NEVER write the same prompt twice again !
    
    Your productivity will go through the ROOF 🚀




🎯 Mini Practice Task ( Try this on your own ! ) :

    Create a Skill called : "blog-writer"
    
    It should :
        👉 Take a topic as input
        👉 Generate a 1000-word blog post
        👉 Follow YOUR personal writing style
        👉 Include SEO-friendly headings
        👉 Add a catchy intro + strong CTA at the end
    
    Once you build this , you can write blogs in SECONDS !
    
    
    ( Bonus : Create a Skill for code reviews , for creating LinkedIn posts ,
      for summarizing meetings — sky is the limit ! 🌟 )




And THAT is the END of Section 7 : Claude Skills 🎉

See you in the next section , where we'll explore even MORE powerful features of Claude Code !
Until then , keep building 💻 , keep learning 📚 , and stay AWESOME 🚀

'''

# %% [markdown]
# # Mini Task : Build Your Own Skill

# %%
'''

🎯 YOUR CHALLENGE :


Pick ONE repetitive task you do daily / weekly , and turn it into a Skill 💪

Some ideas to get you started :

    👉 LinkedIn Post Writer        ( YOUR style , YOUR voice ! )
    👉 Code Review Assistant        ( YOUR team's standards ! )
    👉 Meeting Notes Summarizer     ( YOUR preferred format ! )
    👉 Resume Reviewer              ( YOUR ATS preferences ! )
    👉 YouTube Script Generator     ( YOUR hook style ! )
    👉 Email Reply Generator        ( YOUR professional tone ! )




📋 Follow the 4-step process :

    1. IDENTIFY    : Is it specialized & repeatable ? ✅
    2. CREATE      : Make the folder + SKILL.md
    3. WRITE       : Add detailed YAML + Markdown body
    4. TEST        : Try it in Claude Code !



🔥 Once you build it , share your Skill with your team —
   THIS is how real AI engineers multiply their productivity !


All the best ! 🚀

'''
